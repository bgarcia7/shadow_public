# %% [markdown]
# <div style="text-align:center;font-size:40px"><h1>Financials</h1></div>

# %% [markdown]
# <p style="font-size:16px">Quarterly revenue and profit. I'd obviously like to look at a lot of the other readily available numbers such as MRR, YOY, etc, but this was primarily to help me build some initial intuition about what growth Shopify has been seeing.<p>

# %%
plot_rev_profit()

# %% [markdown]
# <div style="text-align:center;font-size:40px"><h1>Forum Posts</h1></div>

# %% [markdown]
# <p style="font-size:16px">I scraped around 1.5M posts off the <a href="https://ecommerce.shopify.com/forums"> Shopify Forums </a>. If you take a look around, you'll notice that Shopify has been building <strong>thought leadership</strong> around the entire ecommerce community, not just their clients and direct partners. However, most of the posts are found within the "Shopify Discussion" category, suggesting that these forums are primarily for their clients and users. While we're merely looking at total posts here, <strong>we can cut this data in a myriad of ways to try and sift out some strong leading indicators.</strong><p>

# %%
plot_posts()

# %% [markdown]
# <div style="text-align:center;font-size:40px"><h1>Users</h1></div>

# %% [markdown]
# <p style="font-size:16px">Utilizing some very coarse heuristics, I've sifted the users suspected to be shopify clients/platform users from shopify employees and other members that are engaged in the ecommerce community but don't seem to be shopify clients. While this certainly doesn't amount to the 275,000 clients that Shopify currently serves, the hope is that we're pulling from some distribution that will provide some insights into Shopify's growth.</p>

# %%
plot_users()

# %% [markdown]
# <div style="text-align:center;font-size:40px"><h1>Sentiment Analysis</h1></div>

# %% [markdown]
# <p style="font-size:16px">This is mostly for shits and giggles. I threw together a sentiment classifier and sampled 10,000 posts every month to get some very, very rough pulse on the valence of posts on the forums. This doesn't provide much insight right now, but with a refined model and larger samples, this could help us gauge Shopify's clients' satisfaction with support. </p>

# %%
plot_sentiment()
